# %%
# %pylab inline
# Out:
# Welcome to pylab, a matplotlib-based Python environment [backend: module://IPython.kernel.zmq.pylab.backend_inline].
# For more information, type 'help(pylab)'.

# %%
import sys,os,re,time
import urllib

import numpy as np

from IPython import parallel

# %% [markdown]
# This flickr parsing code is adapted from [here](http://megasnippets.com/source-codes/python/get_random_interesting_image_flickr)

# %%
def extract_urls(html):
    """Extract images URLs from a page."""
    re_imageurl = re.compile(r'src="(http://farm\d+.static.?flickr.com/\d+/\d+_\w+_t.jpg)"',re.IGNORECASE|re.DOTALL)
    urls = re_imageurl.findall(html)
    if len(urls)==0:
        return []
    urls = [url.replace('_t.jpg','_m.jpg') for url in urls]
    return urls

# %%
def urls_for_tag(tag='face', min_images=100, max_pages=20):
    """get urls to flickr images with given tag(s)

    scrapes flickr search page
    """
    urls = []
    page = 1
    while len(urls) < min_images and page <= max_pages:
        url = 'http://www.flickr.com/search/?q=%s&l=cc&ss=0&ct=0&mt=photos&w=all&adv=1&m=tags&page=%i' % (tag, page)
        print "fetching %s" % url
        urlfile = urllib.urlopen(url)
        html= urlfile.read()
        urlfile.close()
        page_urls = extract_urls(html)
        urls.extend(page_urls)
        print "found %i images" % len(urls)
        page += 1
        
    return urls

# %%
urls = urls_for_tag('portrait', 500)
# Out:
# fetching http://www.flickr.com/search/?q=portrait&l=cc&ss=0&ct=0&mt=photos&w=all&adv=1&m=tags&page=1
# found 60 images
# fetching http://www.flickr.com/search/?q=portrait&l=cc&ss=0&ct=0&mt=photos&w=all&adv=1&m=tags&page=2
# found 120 images
# fetching http://www.flickr.com/search/?q=portrait&l=cc&ss=0&ct=0&mt=photos&w=all&adv=1&m=tags&page=3
# found 180 images
# fetching http://www.flickr.com/search/?q=portrait&l=cc&ss=0&ct=0&mt=photos&w=all&adv=1&m=tags&page=4
# found 240 images
# fetching http://www.flickr.com/search/?q=portrait&l=cc&ss=0&ct=0&mt=photos&w=all&adv=1&m=tags&page=5
# found 300 images
# fetching http://www.flickr.com/search/?q=portrait&l=cc&ss=0&ct=0&mt=photos&w=all&adv=1&m=tags&page=6
# found 360 images
# fetching http://www.flickr.com/search/?q=portrait&l=cc&ss=0&ct=0&mt=photos&w=all&adv=1&m=tags&page=7
# found 360 images
# fetching http://www.flickr.com/search/?q=portrait&l=cc&ss=0&ct=0&mt=photos&w=all&adv=1&m=tags&page=8
# found 420 images
# fetching http://www.flickr.com/search/?q=portrait&l=cc&ss=0&ct=0&mt=photos&w=all&adv=1&m=tags&page=9
# found 480 images
# fetching http://www.flickr.com/search/?q=portrait&l=cc&ss=0&ct=0&mt=photos&w=all&adv=1&m=tags&page=10
# found 540 images

# %%
def download_image(url, dest_dir='images'):
    """download an image from a url into a directory

    returns the path to the downloaded image.
    """
    basename = url.rsplit('/', 1)[-1]
    dest = os.path.join(dest_dir, basename)
    if not os.path.exists(dest_dir):
        os.makedirs(dest_dir)
    if os.path.exists(dest):
        print "already have %s" % dest
        return dest
    
    print "downloading %s -> %s" % (url, dest)
    urlf = urllib.urlopen(url)
    data = urlf.read()
    urlf.close()
    with open(dest, 'w') as f:
        f.write(data)
    return dest

# %% [markdown]
# First, initialize OpenCV for simple facial detection

# %%
HAAR_CASCADE_PATH = "haarcascade_frontalface_default.xml"
# if you have opencv installed via homebrew, this would be in
# /usr/local/share/OpenCV/haarcascades/

import cv
storage = cv.CreateMemStorage()
cascade = cv.Load(HAAR_CASCADE_PATH)

# %% [markdown]
# Then define a few functions for extracting faces from images

# %%
def extract_faces(image, faces):
    """Returns any faces in an image in a list of numpy arrays"""
    import numpy as np
    A = np.frombuffer(image.tostring(), dtype=np.uint8).reshape((image.height, image.width, image.nChannels))
    A = A[:,:,::-1]
    face_arrays = []
    for face in faces:
        Aface = A[face[1]:face[1]+face[3],face[0]:face[0]+face[2]]
        face_arrays.append(Aface)
    return face_arrays


def detect_faces(filename):
    """Loads an image into OpenCV, and detects faces

    returns None if no image is found,
    (filename, [list of numpy arrays]) if there are faces
    """
    
    image = cv.LoadImage(filename)
    faces = []
    detected = cv.HaarDetectObjects(image, cascade, storage, 1.2, 2, cv.CV_HAAR_DO_CANNY_PRUNING, (100,100))
    if detected:
        for (x,y,w,h),n in detected:
            faces.append((x,y,w,h))
    if faces:
        return filename, extract_faces(image, faces)

# %% [markdown]
# And finally, a two-step function that downloads an image from a url,
# and detects faces in it.

# %%
def faces_in_url(url):
    """detect faces in an image downloaded from a url"""
    img_path = download_image(url)
    return detect_faces(img_path)

# %% [markdown]
# If the network doesn't work,
# you can just generate a list of paths to images on your computer.
# For instance, these pictures are just everything from my iPhoto thumbnails directory,
# so vary from ~320x240 - 1024x768

# %%
import glob
library = os.path.expanduser("~/Pictures/2012")
pictures = []
for directory, subdirs, files in os.walk(os.path.join(library, 'Thumbnails')):
    for fname in files:
        if fname.endswith('.jpg'):
            pictures.append(os.path.join(directory, fname))

# %% [markdown]
# Or this one, which globs pictures from a particular folder:

# %%
import glob
pictures = glob.glob("images/portrait/*.jpg")

# %% [markdown]
# Let's test our

# %%
for url in urls:
    found = faces_in_url(url)
    if found:
        break

filename, faces = found
for face in faces:
    plt.figure()
    plt.imshow(face)
# Out:
# downloading http://farm9.staticflickr.com/8523/8566909256_26c0950d9a_m.jpg -> images/8566909256_26c0950d9a_m.jpg
# downloading http://farm9.staticflickr.com/8376/8566922716_e6f47b4d14_m.jpg -> images/8566922716_e6f47b4d14_m.jpg
# downloading http://farm9.staticflickr.com/8110/8565833125_fd161e2692_m.jpg -> images/8565833125_fd161e2692_m.jpg
# downloading http://farm9.staticflickr.com/8099/8566880684_4c6cb90947_m.jpg -> images/8566880684_4c6cb90947_m.jpg
# downloading http://farm9.staticflickr.com/8104/8566894350_959b9dd880_m.jpg -> images/8566894350_959b9dd880_m.jpg
# downloading http://farm9.staticflickr.com/8514/8565053833_79c5e83862_m.jpg -> images/8565053833_79c5e83862_m.jpg

# %% [markdown]
# If the network isn't kind to you, we can skip the downloads:

# %%
for p in pictures:
    found = detect_faces(p)
    if found:
        break

filename, faces = found
for face in faces:
    plt.figure()
    plt.imshow(face)

# %% [markdown]
# Hey, that looks like a face!

# %% [markdown]
# # Now in parallel

# %% [markdown]
# First, we connect our parallel Client

# %%
rc = parallel.Client()
all_engines = rc[:]
view = rc.load_balanced_view()

# %% [markdown]
# Then we initialize OpenCV on all of the engines (identical to what we did above)

# %%
# %%px
# HAAR_CASCADE_PATH = "haarcascade_frontalface_default.xml"
#
# import cv
# storage = cv.CreateMemStorage()
# cascade = cv.Load(HAAR_CASCADE_PATH)

# %% [markdown]
# and make sure `extract_faces` is defined everywhere

# %%
all_engines.push(dict(
    extract_faces=extract_faces,
    detect_faces=detect_faces,
    download_image=download_image,
))
# Out:
# <AsyncResult: _push>

# %% [markdown]
# Now we can iterate through all of our pictures, and detect and display any faces we find

# %%
tic = time.time()
# if you are running offline, do this one:
f = detect_faces
source = pictures

# or you can download each image as part of the task:
f = faces_in_url
source = urls


amr = view.map_async(f, source[:1000], ordered=False)
nfound = 0
for r in amr:
    if not r:
        continue
    filename, faces = r
    nfound += len(faces)
    print "%i faces found in %s" % (len(faces), filename)
    for face in faces:
        plt.imshow(face)
        plt.show()

toc = time.time()

print "found %i faces in %i images in %f s" % (nfound, len(amr), toc-tic)
# Out:
# 1 faces found in images/8565053833_79c5e83862_m.jpg
# 1 faces found in images/8566689726_8c79daaa9e_m.jpg
# 1 faces found in images/8566309808_696288cfa9_m.jpg
# 1 faces found in images/8564917437_6ed4e02e79_m.jpg
# 1 faces found in images/8564883411_972f7a78fa_m.jpg
# 1 faces found in images/8565906084_542f933224_m.jpg
# 1 faces found in images/8565911946_5da1605cfd_m.jpg
# 1 faces found in images/8564281235_db259f5d8e_m.jpg
# 1 faces found in images/8564289709_60ab21c611_m.jpg
# 1 faces found in images/8564851856_68354e4a05_m.jpg
# 1 faces found in images/8565310778_7d468d5fd5_m.jpg
# 1 faces found in images/8563748627_9c3eca8aa0_m.jpg
# 1 faces found in images/8564762406_fdbd3360cd_m.jpg
# 1 faces found in images/8564751430_c419d91126_m.jpg
# 1 faces found in images/8564761974_6112df8706_m.jpg
# 1 faces found in images/8563603121_1e77647877_m.jpg
# 1 faces found in images/8564623958_0dbcd1c770_m.jpg
# 1 faces found in images/8564625412_acf2f1a903_m.jpg
# 1 faces found in images/8563521963_3e69b1a430_m.jpg
# 1 faces found in images/8564619938_23f83f0d2f_m.jpg
# 1 faces found in images/8563529773_30bcf2fbce_m.jpg
# 1 faces found in images/8563383213_b7b6bce50b_m.jpg
# 1 faces found in images/8563526455_7fb36bd477_m.jpg
# 1 faces found in images/8563389503_34409786ff_m.jpg
# 1 faces found in images/8563356953_fb799884da_m.jpg
# 1 faces found in images/8564454202_2a1c3ebb97_m.jpg
# found 26 faces in 540 images in 17.247942 s
